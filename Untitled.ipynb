# %%
"""
========
Barchart
========

A bar plot with errorbars and height labels on individual bars
"""
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

N = 5
men_means = (20, 35, 30, 35, 27)
men_std = (2, 3, 4, 1, 2)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
#rects1 = ax.bar(ind, men_means, width, color='r', yerr=men_std)
rects1 = ax.bar(ind, men_means)

women_means = (25, 32, 34, 20, 25)
women_std = (3, 5, 2, 3, 3)
#rects2 = ax.bar(ind + width, women_means, width, color='y', yerr=women_std)

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))

#ax.legend((rects1[0], rects2[0]), ('Men', 'Women'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

#autolabel(rects1)
#autolabel(rects2)

plt.show()

# %%
subscriber = 16000
customer = 7000
viagens_por_inscricao = pd.Series([subscriber,customer],index=['Subscriber','Customer'])
viagens_por_inscricao.plot(kind='bar')

# %%
# a stacked bar plot with errorbars
import numpy as np
import matplotlib.pyplot as plt


N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, color='#d62728', yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %%
"""
========
Barchart
========

A bar plot with errorbars and height labels on individual bars
"""
import numpy as np
import matplotlib.pyplot as plt

N = 5
men_means = (20, 35, 30, 35, 27)
men_std = (2, 3, 4, 1, 2)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, men_means, width, color='r', yerr=men_std)

women_means = (25, 32, 34, 20, 25)
women_std = (3, 5, 2, 3, 3)
rects2 = ax.bar(ind + width, women_means, width, color='y', yerr=women_std)

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))

ax.legend((rects1[0], rects2[0]), ('Men', 'Women'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %%
dados = [subscriber,customer]
indices = np.arange(len(dados))
plt.bar(indices,dados)
plt.title('Viagens por tipo de conta')
plt.ylabel('Número de Viagens')
plt.xticks([0,1], ('G1', 'G2'))
plt.show()

# %%
#mu, sigma = 100, 15
#x = mu + sigma * np.random.randn(10000)
#print(x)
x = [1,1,2,3,4,5,6,5,4,3,21,1,1]
maximo = int(max(x)/5)
print(maximo)
indices = np.arange(int(max(x)/5))*5
print(x)
print(indices)

# the histogram of the data
plt.hist(x,bins=indices)


#plt.xlabel('Smarts')
#plt.ylabel('Probability')
#plt.title('Histogram of IQ')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#plt.axis([40, 160, 0, 0.03])
#plt.grid(True)
plt.show()
# Out:
# 4
# [1, 1, 2, 3, 4, 5, 6, 5, 4, 3, 21, 1, 1]
# [ 0  5 10 15]

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
#plt.plot(X,S)

plt.show()

# %%
ax3 = plt.subplot(G[1,:])
#ax4 = plt.subplot(2,2,4)
viagens_por_mes_ano = trip_data.groupby(['start_year','start_month'])
total_viagens_por_mes_ano={}
total_viagens_por_mes_ano['total'] = viagens_por_mes_ano['duration'].count()
total_viagens_por_mes_ano['ano_anterior'] = total_viagens_por_mes_ano['total'].shift()
total_viagens_por_mes_ano['diferenca'] = total_viagens_por_mes_ano['total'].sub(total_viagens_por_mes_ano['ano_anterior'])
total_viagens_por_mes_ano['percentual'] = total_viagens_por_mes_ano['diferenca'] / total_viagens_por_mes_ano['ano_anterior'] * 100
#print(total_viagens_por_mes_ano['diferenca'][2:])
#total_viagens_por_mes_ano['percentual'][2:].plot(kind='bar',ax=ax3)
g4 = total_viagens_por_mes_ano['diferenca'][2:].plot(kind='bar',ax=ax3)
#g4 = ax2.bar([2014,2015],total_viagens_por_ano['percentual'][1:3])
#ax2.set_xticks([2014,2015])
#autolabel(g4,ax2)
#plt.title('Crescimento percentual das viagens em relação ao ano anterior')
#plt.xlabel('Ano')
#plt.ylabel('Porcentagem de crescimento')
#plt.show()

#print(trip_data['duration'])
#trip_data['duration'].plot()
#viagens_por_data = trip_data.groupby(['start_year','start_month'])
#contagem_viagens_por_data = viagens_por_data.size()
#print(contagem_viagens_por_data.head())
#g5 = viagens_por_data.size().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-cf74c5120619> in <module>()
# ----> 1 ax3 = plt.subplot(G[1,:])
#       2 #ax4 = plt.subplot(2,2,4)
#       3 viagens_por_mes_ano = trip_data.groupby(['start_year','start_month'])
#       4 total_viagens_por_mes_ano={}
#       5 total_viagens_por_mes_ano['total'] = viagens_por_mes_ano['duration'].count()
#
# NameError: name 'G' is not defined
